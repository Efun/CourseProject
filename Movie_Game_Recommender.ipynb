# %% [markdown]
# <a href="https://colab.research.google.com/github/Efun/CourseProject/blob/main/Movie_Game_Recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Downloading/Cleaning/Parsing Dataset

# %%
import pandas as pd
import json

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! kaggle datasets download trolukovich/steam-games-complete-dataset
# Out:
# steam-games-complete-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip steam-games-complete-dataset.zip
# Out:
# Archive:  steam-games-complete-dataset.zip
# replace steam_games.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: steam_games.csv

# %%
steam = pd.read_csv("/steam_games.csv")
movies = pd.read_csv("/tmdb_5000_movies.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-cadcbce4fcd4> in <module>
# ----> 1 steam = pd.read_csv("/steam_games.csv")
#       2 movies = pd.read_csv("/tmdb_5000_movies.csv")
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
steam.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# ...

# %%
steam_cleaned = steam[["desc_snippet", "name", "developer", "publisher", "popular_tags", "game_details", "genre"]]

# %%
steam_parsed = steam_cleaned.dropna(subset=['desc_snippet'])

# %%
steam_parsed
# Out:
#                                             desc_snippet  \
# 0      Now includes all three premium DLC packs (Unto...
# 1      PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2      Take command of your own mercenary outfit of '...
# 3      The post-soviet country of Chernarus is struck...
# 4      EVE Online is a community-driven spaceship MMO...
# ...                                                  ...
# 40823  We are the largest CS:GO club in the world. Ou...
# 40824  The power of black holes in your hands. Gravia...
# 40825  Galactis is a single-player space shooter wher...
# 40826  Welcome to Alive , a Third person Cover based ...
# 40832  An RPG about a tribe exploring an ancient worl...
#
#                                 name            developer  \
# 0                               DOOM          id Software
# 1      PLAYERUNKNOWN'S BATTLEGROUNDS     PUBG Corporation
# 2                         BATTLETECH  Harebrained Schemes
# ...

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_cleaned = movies[["genres", "keywords", "title", "overview", "production_companies", "tagline"]]

# %%
movies_cleaned.iloc[0]
# Out:
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# title                                                              Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# tagline                                       Enter the World of Pandora.
# Name: 0, dtype: object

# %%
movies_parsed = movies_cleaned[["title", "overview", "tagline"]]
movies_parsed['genres'] = movies_cleaned['genres'].map(lambda x: ",".join(map(lambda y: y['name'], json.loads(x))))
movies_parsed['keywords'] = movies_cleaned['keywords'].map(lambda x: ",".join(map(lambda y: y['name'], json.loads(x))))
movies_parsed['production_companies'] = movies_cleaned['production_companies'].map(lambda x: ",".join(map(lambda y: y['name'], json.loads(x))))
movies_parsed = movies_parsed.dropna(subset=['overview', 'keywords', 'title'])
# Out:
# <ipython-input-13-2301ea46831c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_parsed['genres'] = movies_cleaned['genres'].map(lambda x: ",".join(map(lambda y: y['name'], json.loads(x))))
# <ipython-input-13-2301ea46831c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_parsed['keywords'] = movies_cleaned['keywords'].map(lambda x: ",".join(map(lambda y: y['name'], json.loads(x))))

# %%
movies_parsed
# Out:
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...

# %%
movies_parsed.to_csv('movies_parsed.csv')
steam_parsed.to_csv('steam_parsed.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8a65e38c9ecd> in <module>
# ----> 1 movies_parsed.to_csv('movies_parsed.csv')
#       2 steam_parsed.to_csv('steam_parsed.csv')
#
# NameError: name 'movies_parsed' is not defined

# %% [markdown]
# # Creating Inverted Index

# %%
# !pip install faiss-gpu
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85.5 MB 87 kB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 33.2 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 59.9 MB/s
# ...
#      |████████████████████████████████| 182 kB 53.5 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 61.4 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=04a5c89d39869f66c92a2c846b1615c3aa551cc74dc45d306e69db3981cb1b04
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence-transformers
# ...

# %%
import numpy as np
import torch
import os
import pandas as pd
import faiss
import time
from sentence_transformers import SentenceTransformer, util

# %%
movies = pd.read_csv('/movies_parsed.csv')
steam = pd.read_csv('/steam_parsed.csv')

# %%
steam.head()
# Out:
#    Unnamed: 0                                       desc_snippet  \
# 0           0  Now includes all three premium DLC packs (Unto...
# 1           1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2           2  Take command of your own mercenary outfit of '...
# 3           3  The post-soviet country of Chernarus is struck...
# 4           4  EVE Online is a community-driven spaceship MMO...
#
#                             name            developer  \
# 0                           DOOM          id Software
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS     PUBG Corporation
# 2                     BATTLETECH  Harebrained Schemes
# 3                           DayZ  Bohemia Interactive
# 4                     EVE Online                  CCP
#
#                                  publisher  \
# 0    Bethesda Softworks,Bethesda Softworks
# 1        PUBG Corporation,PUBG Corporation
# 2  Paradox Interactive,Paradox Interactive
# 3  Bohemia Interactive,Bohemia Interactive
# ...

# %%
movies.head()
# Out:
#    Unnamed: 0                                     title  \
# 0           0                                    Avatar
# 1           1  Pirates of the Caribbean: At World's End
# 2           2                                   Spectre
# 3           3                     The Dark Knight Rises
# 4           4                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# ...

# %%
movies_data = movies['overview'].to_list()
steam_data = steam['desc_snippet'].to_list()

# %%
# model = SentenceTransformer('msmarco-distilbert-base-v4')
model = SentenceTransformer('all-mpnet-base-v2')
# model = SentenceTransformer()
encoded_movies_data = model.encode(movies_data)
encoded_steam_data = model.encode(steam_data)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
encoded_movies_data.shape
# Out:
# (4800, 768)

# %%
movies_index = faiss.IndexIDMap(faiss.IndexFlatIP(768))
movies_index.add_with_ids(encoded_movies_data, np.array(range(0, len(movies_data))))

steam_index = faiss.IndexIDMap(faiss.IndexFlatIP(768))
steam_index.add_with_ids(encoded_steam_data, np.array(range(0, len(steam_data))))

# %%
faiss.write_index(movies_index, 'movies_index_symmetric')
faiss.write_index(steam_index, 'steam_index_symmetric')

# %%
movies_index = faiss.read_index('movies_index_symmetric')
steam_index = faiss.read_index('steam_index_symmetric')

# %%
res = faiss.StandardGpuResources()
gpu_movies_index = faiss.index_cpu_to_gpu(res, 0, movies_index)
gpu_steam_index = faiss.index_cpu_to_gpu(res, 0, steam_index)

# %%
# print(movies.iloc[0])
# print(movies.iloc[0].overview)
query = model.encode([movies.iloc[0].overview])
top_k = gpu_steam_index.search(query, 10)
print(top_k)
# print([steam.iloc[_id]['name'] for _id in top_k[1].tolist()[0]])
# Out:
# (array([[0.5556568 , 0.50862455, 0.49599984, 0.49293274, 0.47540915,
#         0.46753997, 0.456048  , 0.45546663, 0.45491445, 0.45304477]],
#       dtype=float32), array([[ 4414,   286,  3666,  5018, 15801, 11385,  2101,  7079,  8749,
#           588]]))

# %%
print(steam.iloc[1])
print(steam.iloc[1].desc_snippet)
query = model.encode([steam.iloc[1].desc_snippet])
top_k = gpu_movies_index.search(query, 10)
print([movies.iloc[_id]['title'] for _id in top_k[1].tolist()[0]])
# Out:
# Unnamed: 0                                                      1
# desc_snippet    PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# name                                PLAYERUNKNOWN'S BATTLEGROUNDS
# developer                                        PUBG Corporation
# publisher                       PUBG Corporation,PUBG Corporation
# popular_tags    Survival,Shooter,Multiplayer,Battle Royale,PvP...
# game_details               Multi-player,Online Multi-Player,Stats
# genre                      Action,Adventure,Massively Multiplayer
# Name: 1, dtype: object
# PLAYERUNKNOWN'S BATTLEGROUNDS is a battle royale shooter that pits 100 players against each other in a struggle for survival. Gather supplies and outwit your opponents to become the last person standing.
# ['Stay Alive', "The World's End", 'Gamer', 'Thr3e', 'The FP', 'Pixels', 'ZMD: Zombies of Mass Destruction', 'Mortal Kombat: Annihilation', 'The Hurt Locker', 'The Chronicles of Riddick']

# %%
def recommend_movies_from_game(game_name):
  game_desc = steam.loc[steam['name'] == game_name]['desc_snippet'].values[0]
  genre = steam.loc[steam['name'] == game_name]['genre'].values[0]
  game_genres = genre.split(',')
  query = model.encode([game_desc])
  top_k = gpu_movies_index.search(query, 30)
  mean_score = sum(top_k[0][0]) / 30
  movie_score_dict = {}
  for idx in range(len(top_k[1][0])):
    _id = top_k[1][0][idx]
    movie_genres = movies.iloc[_id]['genres'].split(',')
    genre_reward = 1
    for game_genre in game_genres:
      for movie_genre in movie_genres:
        if game_genre == movie_genre:
          genre_reward += 0.1
    movie_score_dict[movies.iloc[_id]['title']] = top_k[0][0][idx] * genre_reward
  movie_score_dict = dict(sorted(movie_score_dict.items(), key=lambda item: item[1], reverse=True))
  print('Recommended movies: ')
  print(list(movie_score_dict.keys())[:10])

# %%
recommend_movies_from_game("PLAYERUNKNOWN'S BATTLEGROUNDS")
# Out:
# Recommended movies:
# ["The World's End", 'Gamer', 'Pixels', 'Stay Alive', 'Mortal Kombat: Annihilation', 'The Chronicles of Riddick', 'Thr3e', 'The FP', 'ZMD: Zombies of Mass Destruction', 'Predators']

# %%
recommend_movies_from_game("DOOM")
# Out:
# Recommended movies:
# ['Resident Evil: Apocalypse', 'Re-Kill', 'Evil Dead', 'Fantasia 2000', 'The Bourne Ultimatum', 'G.I. Joe: The Rise of Cobra', 'Insidious: Chapter 3', 'Indie Game: The Movie', 'Virtuosity', 'The Bourne Legacy']
